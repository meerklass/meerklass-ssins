# %% [markdown]
# ## **Sky-Subtraction Methods Comparision Notebook**
# The following notebook evalutes and compares the various sky-subtraction methods that we have developed to date.  In this notebook we will evalute wether the sky removal methods has sufficiently removed the astrophysical sky from our data, we will also perform statistical checks on the residual data, this will allow us to understand the distribution of the residual data.  The first comparison checks we perform are done on data from observation block 1630519596.

# %%
import os
import sys
sys.path.append(os.path.abspath('.'))
import mkssins
from mkssins import *
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# In the next cell we define the observation block and path to the specific level masks we are working with. In this case we using observation block : 1630519596 and Level 1 masks for the data.

# %%
fname = '1632760885' 
path = '/idia/projects/hi_im/raw_vis/MeerKLASS2021/level1/mask/checked/'
pol = 'h'

# %%
mkssins.good_ant(fname)
# Out:
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# ['m000',
#  'm001',
#  'm002',
#  'm003',
#  'm004',
#  'm005',
#  'm006',
#  'm007',
#  'm009',
#  'm010',
#  'm011',
#  'm012',
#  'm013',
#  'm014',
#  'm015',
#  'm016',
#  'm017',
#  'm018',
#  'm019',
#  'm020',
#  'm021',
#  'm022',
#  'm023',
#  'm024',
#  'm025',
#  'm026',
#  'm027',
#  'm028',
#  'm029',
#  'm030',
#  'm031',
#  'm032',
#  'm036',
#  'm037',
#  'm038',
#  'm039',
#  'm040',
#  'm041',
#  'm042',
#  'm043',
#  'm044',
#  'm045',
#  'm046',
#  'm047',
#  'm048',
#  'm049',
#  'm050',
#  'm051',
#  'm053',
#  'm054',
#  'm055',
#  'm056',
#  'm057',
#  'm058',
#  'm059',
#  'm061',
#  'm062',
#  'm063']

# %%
def ants_checked_L1(fname, path):
    ants =[]
    obsblock_ant_pol = []
    obsfolder = Path(path)
    for f in sorted(obsfolder.glob(fname+'_m*h*')):
        filename =  f.name.split('_')[0]
        #print(filename)
        antpol = f.name.split(fname+'_')[1]
        #print(antpol)
        ant= antpol[0:4].split('h')
        ants.append(ant)
        pol = antpol[4:5]
    
       
    return(ants)

# %%
#just checking the mkssins.py module

ants = ants_checked_L1(fname, path)


for ant in ants:
    print(ant)
# Out:
# ['m000']
# ['m001']
# ['m002']
# ['m003']
# ['m004']
# ['m005']
# ['m006']
# ['m007']
# ['m009']
# ['m010']
# ['m011']
# ['m012']
# ['m014']
# ['m016']
# ['m017']
# ['m018']
# ['m019']
# ['m020']
# ['m022']
# ['m023']
# ['m026']
# ['m027']
# ['m028']
# ['m029']
# ['m032']
# ['m040']
# ['m041']
# ['m042']
# ['m043']
# ['m046']
# ['m048']
# ['m049']
# ['m050']
# ['m053']
# ['m058']
# ['m059']
# ['m062']

# %% [markdown]
#  In the nest cell we  will loop over the ants in the list of antennas with masks and access the visData function from mkssins.py, we are storing the visibility products and the noise_diodes as seperate dictionaries, with 'ant' being the key for the values in the respective dictionaries. Also note we can add flags (SARAO Prior flags as well using the same approach)

# %%
# %time

raw_vis_dict = {}
nd_flags_dict ={}

for ant in ants:
    vis,nd_s0 = mkssins.visData(fname, ant[0] , pol) # replace ant[0] and remove loop for extracting the antenna as a string from the list
    raw_vis_dict[ant[0]] = vis
    nd_flags_dict[ant[0]] = nd_s0
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m000h' 'm000h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m001h' 'm001h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m002h' 'm002h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m003h' 'm003h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m004h' 'm004h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m005h' 'm005h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m006h' 'm006h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m007h' 'm007h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m009h' 'm009h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m010h' 'm010h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m011h' 'm011h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m012h' 'm012h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m014h' 'm014h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'scan_azel_with_nd_trigger' in catalogue
# calibrator: PKS1934-638, ra,dec= 294d51m15.39s, -63d42m45.6264s
# bad_ants: []
# m063 is bad
# # loaded data was saved in python2
# ['m016h' 'm016h']
# edge number 0-373
# *** diode 0 was fired out of timestamps list: -18.900585889816284 not in [0,7270.923981666565]
# # checked: len(nd_0)+len(nd_1x)==len(timestamps)

# %%
raw_vis_dict.keys()  #checking the  raw vis  dictionary
# Out:
# dict_keys(['m001', 'm002', 'm003', 'm004', 'm005', 'm006', 'm007', 'm008', 'm009', 'm010', 'm011', 'm012', 'm013', 'm015', 'm016', 'm017', 'm018', 'm019', 'm020', 'm021', 'm022', 'm023', 'm025', 'm026', 'm027', 'm028', 'm030', 'm031', 'm032', 'm034', 'm036', 'm037', 'm038', 'm039', 'm040', 'm041', 'm042', 'm043', 'm044', 'm045', 'm046', 'm047', 'm048', 'm050', 'm051', 'm052', 'm053', 'm054', 'm055', 'm056', 'm057', 'm058', 'm059', 'm061', 'm062', 'm063'])

# %%
nd_flags_dict.keys() #checking the noise diode flags  dictionary
# Out:
# dict_keys(['m001', 'm002', 'm003', 'm004', 'm005', 'm006', 'm007', 'm008', 'm009', 'm010', 'm011', 'm012', 'm013', 'm015', 'm016', 'm017', 'm018', 'm019', 'm020', 'm021', 'm022', 'm023', 'm025', 'm026', 'm027', 'm028', 'm030', 'm031', 'm032', 'm034', 'm036', 'm037', 'm038', 'm039', 'm040', 'm041', 'm042', 'm043', 'm044', 'm045', 'm046', 'm047', 'm048', 'm050', 'm051', 'm052', 'm053', 'm054', 'm055', 'm056', 'm057', 'm058', 'm059', 'm061', 'm062', 'm063'])

# %% [markdown]
#  Similary in the next cell we can create a dictionary for the mask of the flags from the Level 1 folder. We use the try/except method to check for _mask2 / _mask flag masks for each receiver.

# %%
l1_flags_dict = {}
mask_dir = Path('/idia/projects/hi_im/raw_vis/MeerKLASS2021/level1/mask/checked/')
for dish, (vis) in raw_vis_dict.items():
    
    try:
        with open(mask_dir / f'{fname}_{dish}_mask2', 'rb') as f:
            d3 = pickle.load(f)
            print (f'mask2 loaded for dish {dish}')
    except(Exception):
        with open(mask_dir / f'{fname}_{dish}_mask', 'rb')as f:
            d3 = pickle.load(f)
            print (f'mask loaded for dish {dish}')
    mask_flags=d3['mask']
    l1_flags_dict[dish]  = mask_flags
    
        
   
    #print(dish)
# Out:
# mask loaded for dish m001
# mask loaded for dish m002
# mask loaded for dish m003
# mask loaded for dish m004
# mask loaded for dish m005
# mask loaded for dish m006
# mask loaded for dish m007
# mask loaded for dish m008
# mask loaded for dish m009
# mask loaded for dish m010
# mask loaded for dish m011
# mask loaded for dish m012
# mask loaded for dish m013
# mask loaded for dish m015
# mask loaded for dish m016
# mask loaded for dish m017
# mask loaded for dish m018
# mask loaded for dish m019
# mask loaded for dish m020
# mask loaded for dish m021
# mask loaded for dish m022
# mask loaded for dish m023
# mask loaded for dish m025
# mask loaded for dish m026
# mask loaded for dish m027
# mask loaded for dish m028
# mask loaded for dish m030
# mask loaded for dish m031
# mask loaded for dish m032
# mask loaded for dish m034
# mask loaded for dish m036
# mask loaded for dish m037
# mask loaded for dish m038
# mask loaded for dish m039
# mask loaded for dish m040
# mask loaded for dish m041
# mask loaded for dish m042
# mask loaded for dish m043
# mask loaded for dish m044
# mask loaded for dish m045
# mask loaded for dish m046
# mask loaded for dish m047
# mask loaded for dish m048
# mask loaded for dish m050
# mask loaded for dish m051
# mask loaded for dish m052
# mask loaded for dish m053
# mask loaded for dish m054
# mask loaded for dish m055
# mask loaded for dish m056
# mask loaded for dish m057
# mask loaded for dish m058
# mask loaded for dish m059
# mask loaded for dish m061
# mask loaded for dish m062
# mask loaded for dish m063

# %%
l1_flags_dict.keys() #checking level1 flags dictionary
# Out:
# dict_keys(['m001', 'm002', 'm003', 'm004', 'm005', 'm006', 'm007', 'm008', 'm009', 'm010', 'm011', 'm012', 'm013', 'm015', 'm016', 'm017', 'm018', 'm019', 'm020', 'm021', 'm022', 'm023', 'm025', 'm026', 'm027', 'm028', 'm030', 'm031', 'm032', 'm034', 'm036', 'm037', 'm038', 'm039', 'm040', 'm041', 'm042', 'm043', 'm044', 'm045', 'm046', 'm047', 'm048', 'm050', 'm051', 'm052', 'm053', 'm054', 'm055', 'm056', 'm057', 'm058', 'm059', 'm061', 'm062', 'm063'])

# %%
from collections import defaultdict #stackexchange suggestion

d1 = l1_flags_dict
d2 = raw_vis_dict
d3 = nd_flags_dict

dd = defaultdict(list)

for d in (d1, d2, d3): # you can list as many input dicts as y
    for key, value in d.items():
        dd[key].append(value)
    
print(dd) # result: defaultdict(<type 'list'>, {1: [2, 6], 3: [4, 7]})
# Out:
# defaultdict(<class 'list'>, {'m001': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2961.96386719,   69.69976807,   69.67485046, ...,    0.        ,
#            0.        ,    0.        ],
#        [2965.95263672,   69.55400848,   69.63220978, ...,   77.63027954,
#           78.18206787,   79.22492218],
#        [2963.65820312,   69.61795807,   69.70906067, ...,   77.59899139,
#           78.13063812,   79.28348541],
#        ...,
#        [2876.484375  ,   74.53998566,   74.65919495, ...,   68.84125519,
#           69.46418762,   70.37210083],
#        [2882.86621094,   77.34767151,   77.30288696, ...,   69.49137878,
#           69.93612671,   71.14952087],
#        [2945.41699219,  107.20745087,  107.17047119, ...,   77.67912292,
#           77.76540375,   78.73025513]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm002': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2297.38867188,   60.59336853,   60.6210289 , ...,    0.        ,
#            0.        ,    0.        ],
#        [2295.57202148,   60.67831039,   60.67993546, ...,   60.88637161,
#           61.1393013 ,   61.96967697],
#        [2295.53564453,   60.70194626,   60.5696106 , ...,   60.79748917,
#           61.06725693,   61.84429169],
#        ...,
#        [2274.50195312,   62.51613617,   62.68463516, ...,   54.05098343,
#           54.27084351,   55.05333328],
#        [2278.48779297,   64.83290863,   64.85674286, ...,   55.63479233,
#           55.87839508,   57.13911438],
#        [2337.41503906,   88.65350342,   88.48600006, ...,   72.83866119,
#           73.15660858,   74.14916229]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm003': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1536.13061523,   40.60214233,   40.52910233, ...,    0.        ,
#            0.        ,    0.        ],
#        [1537.77148438,   40.66357422,   40.63639069, ...,   50.92757797,
#           51.01748276,   51.84043503],
#        [1536.14624023,   40.61832809,   40.58623886, ...,   50.77170181,
#           51.0218277 ,   51.74611282],
#        ...,
#        [1588.66967773,   42.65610886,   42.76054382, ...,   46.98865128,
#           47.19681549,   48.29837418],
#        [1591.95068359,   44.59919357,   44.57532501, ...,   48.04755783,
#           48.40808487,   49.0538559 ],
#        [1630.35668945,   64.02029419,   63.93453217, ...,   60.84898376,
#           60.94720078,   61.83205032]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm004': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2634.65991211,   72.36343384,   72.44574738, ...,    0.        ,
#            0.        ,    0.        ],
#        [2637.13085938,   72.21372223,   72.32491302, ...,   44.72554779,
#           44.85446548,   45.49707031],
#        [2638.13867188,   72.18669128,   72.38598633, ...,   44.59668732,
#           44.84775925,   45.60401154],
#        ...,
#        [2669.90942383,   76.44207764,   76.25278473, ...,   40.98371887,
#           41.21854401,   41.68881607],
#        [2675.04541016,   79.36699677,   79.23441315, ...,   42.08805466,
#           42.24090958,   42.89374161],
#        [2735.4309082 ,  109.71237946,  109.6672287 , ...,   54.89011383,
#           55.12632751,   55.92675781]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm005': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[3644.80981445,   50.21009827,   50.25580215, ...,    0.        ,
#            0.        ,    0.        ],
#        [3647.16943359,   50.2144928 ,   50.38193512, ...,   45.68762589,
#           45.99783707,   46.43615723],
#        [3645.32861328,   50.35054779,   50.32086182, ...,   45.55708694,
#           45.82792664,   46.32209015],
#        ...,
#        [3613.29150391,   52.22373962,   52.19577026, ...,   41.37496185,
#           41.78683853,   42.39798737],
#        [3618.11254883,   53.89192581,   53.88179779, ...,   42.42889404,
#           42.68903732,   43.3511734 ],
#        [3664.19580078,   70.4230957 ,   70.33971405, ...,   52.15163422,
#           52.57913589,   53.16937256]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm006': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2409.05908203,   87.23538208,   87.28496552, ...,    0.        ,
#            0.        ,    0.        ],
#        [2409.57006836,   87.59925079,   87.33796692, ...,   60.4237442 ,
#           61.00129318,   61.77750778],
#        [2412.5925293 ,   87.24851227,   87.33959961, ...,   60.6031456 ,
#           60.7835083 ,   61.72018814],
#        ...,
#        [2552.03710938,   92.31653595,   92.42666626, ...,   55.28667068,
#           55.61849594,   56.31953049],
#        [2557.84326172,   95.65866852,   95.68639374, ...,   56.583004  ,
#           57.12286758,   57.80703354],
#        [2630.42285156,  131.56265259,  131.50009155, ...,   71.80409241,
#           72.51239014,   73.48803711]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm007': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1453.37719727,   69.23965454,   69.17575836, ...,    0.        ,
#            0.        ,    0.        ],
#        [1453.53662109,   69.26990509,   69.27229309, ...,   49.92483521,
#           50.33889771,   51.40828705],
#        [1453.41271973,   69.28102112,   69.37678528, ...,   50.05060577,
#           50.50004196,   51.12018204],
#        ...,
#        [1559.47753906,   73.63553619,   73.5669632 , ...,   46.17508316,
#           46.31206131,   47.23031235],
#        [1563.15686035,   75.96376801,   76.45645142, ...,   47.05586624,
#           47.24261856,   48.05130768],
#        [1608.51867676,  105.9284668 ,  106.08810425, ...,   56.63154984,
#           57.07885361,   57.86632538]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm008': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2031.15466309,   34.68847275,   34.67009354, ...,    0.        ,
#            0.        ,    0.        ],
#        [2030.86010742,   34.69274521,   34.67253113, ...,   47.17866516,
#           47.24143219,   48.3951416 ],
#        [2030.36730957,   34.75350571,   34.70667267, ...,   47.00975418,
#           47.36539459,   47.96984863],
#        ...,
#        [2098.69824219,   37.23615646,   37.26257324, ...,   41.49023056,
#           41.76625061,   42.72976685],
#        [2102.28125   ,   38.46118546,   38.46665573, ...,   41.84436798,
#           42.05584717,   42.74789429],
#        [2131.24023438,   51.56366348,   51.57012939, ...,   45.62229538,
#           45.85442734,   46.68157578]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm009': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1414.06872559,   42.45542526,   41.4982605 , ...,    0.        ,
#            0.        ,    0.        ],
#        [1410.69848633,   42.46104813,   41.36108017, ...,   48.3980751 ,
#           48.51112747,   55.93169022],
#        [1412.43151855,   42.52084732,   41.52885818, ...,   48.69891739,
#           48.82756042,   55.71988678],
#        ...,
#        [1479.62475586,   45.23099518,   44.09847641, ...,   43.55289841,
#           43.73802567,   50.13797379],
#        [1482.87658691,   46.72081375,   45.59489441, ...,   43.98186874,
#           44.18202972,   50.45863342],
#        [1517.13171387,   62.41679001,   61.05528259, ...,   49.5267334 ,
#           49.60303116,   56.76482773]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm010': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[3448.90136719,   73.3204422 ,   73.37288666, ...,    0.        ,
#            0.        ,    0.        ],
#        [3448.98876953,   73.23136902,   73.35642242, ...,   79.04442596,
#           79.41299438,   81.34091949],
#        [3448.13183594,   73.06451416,   73.13951874, ...,   79.42722321,
#           79.79504395,   81.0766983 ],
#        ...,
#        [3386.34594727,   79.11064148,   79.25370789, ...,   69.40114594,
#           69.89864349,   71.0324173 ],
#        [3392.19750977,   81.81774139,   81.93156433, ...,   70.69808197,
#           71.07315826,   71.96476746],
#        [3463.34448242,  112.09486389,  111.72975159, ...,   82.49662018,
#           83.3095932 ,   84.14727783]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm011': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2095.87207031,   33.17923355,   33.17316055, ...,    0.        ,
#            0.        ,    0.        ],
#        [2093.72705078,   33.19452667,   33.27281952, ...,   41.41970825,
#           41.66991425,   42.15248871],
#        [2094.97265625,   33.17853165,   33.18750763, ...,   41.39117813,
#           41.66264343,   42.32312775],
#        ...,
#        [2040.01293945,   34.84445953,   34.853302  , ...,   36.90520859,
#           37.15464783,   37.54631805],
#        [2042.5189209 ,   36.01488495,   36.15378571, ...,   38.29668427,
#           38.35232162,   38.92012787],
#        [2078.03833008,   48.45616913,   48.17826843, ...,   50.5667572 ,
#           50.71496201,   51.53369141]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm012': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2498.35205078,   40.82543182,   41.10465622, ...,    0.        ,
#            0.        ,    0.        ],
#        [2498.18676758,   40.95439148,   41.03045654, ...,   65.30667877,
#           65.67525482,   66.66168976],
#        [2498.88256836,   40.85206223,   40.92412186, ...,   65.3374939 ,
#           65.73609924,   66.70566559],
#        ...,
#        [2661.64990234,   43.63265991,   43.56482697, ...,   57.35315323,
#           57.5741806 ,   58.43684769],
#        [2666.06103516,   44.99580765,   44.95404434, ...,   57.59067917,
#           57.99993896,   58.70170975],
#        [2710.71484375,   59.55277252,   59.61019135, ...,   60.11891937,
#           60.43253326,   61.20922852]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm013': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2085.33374023,   58.7124176 ,   58.85410309, ...,    0.        ,
#            0.        ,    0.        ],
#        [2084.34033203,   58.76602554,   58.95664978, ...,   62.55911255,
#           63.06912613,   63.90396881],
#        [2085.78613281,   58.77561951,   58.96417618, ...,   62.41864777,
#           62.94227982,   63.92616272],
#        ...,
#        [2217.17626953,   63.83489609,   63.989151  , ...,   53.51370621,
#           53.93615723,   54.73610687],
#        [2219.66552734,   66.20848083,   66.22543335, ...,   54.97920227,
#           55.15404129,   56.10302353],
#        [2267.54077148,   90.35795593,   89.95002747, ...,   69.50953674,
#           69.98975372,   70.75852203]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm015': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1750.75976562,   85.82537842,   86.01195526, ...,    0.        ,
#            0.        ,    0.        ],
#        [1748.07543945,   86.00668335,   86.33287811, ...,   42.90728378,
#           43.4322052 ,   44.06951523],
#        [1749.98193359,   85.89485931,   85.89286804, ...,   43.05932617,
#           43.3061142 ,   43.8771019 ],
#        ...,
#        [1739.16162109,   94.57201385,   94.66422272, ...,   37.04508972,
#           37.26895905,   37.8273735 ],
#        [1742.64343262,   98.65184021,   98.84955597, ...,   37.85145187,
#           37.95333099,   38.53823853],
#        [1795.49182129,  140.38163757,  140.21247864, ...,   46.72564697,
#           47.02098083,   47.45924377]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm016': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2479.74804688,   18.83880234,   18.81451416, ...,    0.        ,
#            0.        ,    0.        ],
#        [2479.91479492,   18.84850311,   18.81408691, ...,   53.81274033,
#           53.93841171,   54.88205719],
#        [2479.91235352,   18.79631615,   18.8058548 , ...,   53.35779572,
#           53.97017288,   54.87424088],
#        ...,
#        [2479.27490234,   20.1253624 ,   20.18369102, ...,   46.79452515,
#           47.04184723,   47.85114288],
#        [2481.9309082 ,   20.71245575,   20.7395668 , ...,   47.56540298,
#           47.7732048 ,   48.53367996],
#        [2506.23779297,   26.89051056,   27.01788521, ...,   55.20480347,
#           55.4273262 ,   56.24397659]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm017': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2591.31982422,   56.88567734,   56.65849304, ...,    0.        ,
#            0.        ,    0.        ],
#        [2591.52246094,   56.85478973,   56.73791885, ...,   60.25945663,
#           60.75114059,   61.64608383],
#        [2590.41772461,   56.62260818,   56.77280807, ...,   60.13857269,
#           60.5554657 ,   61.46485519],
#        ...,
#        [2613.04296875,   60.77210999,   60.74266815, ...,   53.17162323,
#           53.72597122,   54.3045845 ],
#        [2619.74389648,   63.42594147,   63.35384369, ...,   54.26595688,
#           54.56462097,   55.46595001],
#        [2683.11767578,   90.78211212,   91.01574707, ...,   64.5086441 ,
#           64.80760193,   65.5049057 ]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm018': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2382.42553711,   52.5447197 ,   52.68748093, ...,    0.        ,
#            0.        ,    0.        ],
#        [2383.76318359,   52.61557007,   52.6321907 , ...,   43.84862518,
#           44.11802673,   44.70403671],
#        [2383.35229492,   52.55118561,   52.57479477, ...,   43.91960907,
#           44.20317459,   44.9215126 ],
#        ...,
#        [2443.79492188,   55.11359406,   55.13740158, ...,   40.60810471,
#           40.8170166 ,   41.41245651],
#        [2448.87841797,   57.13471603,   57.23878098, ...,   41.19967651,
#           41.5261879 ,   42.02926636],
#        [2493.93505859,   80.32044983,   80.41519928, ...,   47.58045959,
#           47.70731735,   48.37323761]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm019': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1746.83337402,   65.09342957,   65.309021  , ...,    0.        ,
#            0.        ,    0.        ],
#        [1748.47094727,   65.21354675,   65.0484314 , ...,   21.47304916,
#           21.52181053,   21.89373016],
#        [1747.81872559,   64.88835144,   65.1422348 , ...,   21.62130356,
#           21.74340248,   22.11197662],
#        ...,
#        [1629.09777832,   70.81407166,   71.22019958, ...,   18.57977676,
#           18.65162086,   18.94942474],
#        [1631.82055664,   73.9019165 ,   74.26384735, ...,   19.06688118,
#           19.07880592,   19.3909359 ],
#        [1680.05761719,  105.40003204,  105.17685699, ...,   24.20082092,
#           24.21394157,   24.660923  ]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm020': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2211.49755859,   62.58041   ,   62.52151108, ...,    0.        ,
#            0.        ,    0.        ],
#        [2211.52758789,   62.57063675,   62.5848999 , ...,   44.87243652,
#           44.98294067,   45.47505951],
#        [2212.98242188,   62.5297966 ,   62.58778763, ...,   44.82977295,
#           45.08599472,   45.85634613],
#        ...,
#        [2266.94067383,   65.27511597,   65.53923035, ...,   40.64469528,
#           40.84104538,   41.3778801 ],
#        [2268.86523438,   67.83309937,   68.0620575 , ...,   42.06446075,
#           42.20518494,   42.76316452],
#        [2313.96972656,   93.61568451,   93.97229004, ...,   56.04769135,
#           56.38960266,   57.35670853]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm021': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1772.28955078,   61.79799271,   61.93883896, ...,    0.        ,
#            0.        ,    0.        ],
#        [1774.22338867,   61.79658508,   61.96677399, ...,   42.65213013,
#           43.02733612,   43.53349686],
#        [1772.77990723,   61.93335724,   61.75703049, ...,   42.78681564,
#           42.9747963 ,   43.75146103],
#        ...,
#        [1835.60754395,   65.55645752,   65.58501434, ...,   38.03388977,
#           38.14818573,   38.64285278],
#        [1840.22583008,   68.45508575,   68.37924957, ...,   39.26422501,
#           39.36062622,   40.0797348 ],
#        [1884.2199707 ,   97.3011322 ,   97.08867645, ...,   52.3199501 ,
#           52.47821808,   53.27899933]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm022': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1219.6262207 ,   53.50933075,   53.57709885, ...,    0.        ,
#            0.        ,    0.        ],
#        [1219.57275391,   53.47153473,   53.62015915, ...,   36.15191269,
#           36.40109253,   37.04227066],
#        [1219.66381836,   53.35617828,   53.31967163, ...,   36.26322937,
#           36.33588791,   36.89081192],
#        ...,
#        [1233.82177734,   55.98714066,   56.0239563 , ...,   32.89528275,
#           33.09253311,   33.41283417],
#        [1237.80395508,   58.02257919,   58.07405853, ...,   34.17034531,
#           34.33756256,   34.91215515],
#        [1282.59289551,   80.64671326,   81.14899445, ...,   46.95640564,
#           47.03728104,   47.81000519]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm023': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2790.76049805,   39.13023758,   39.10825729, ...,    0.        ,
#            0.        ,    0.        ],
#        [2791.06616211,   39.12685013,   39.10746384, ...,   64.37644958,
#           65.12272644,   65.66880035],
#        [2792.4050293 ,   39.11752701,   39.11610794, ...,   64.67498779,
#           64.72911072,   65.99060822],
#        ...,
#        [2850.36865234,   41.04957581,   40.96037292, ...,   59.25131989,
#           59.15663147,   60.4204216 ],
#        [2857.24316406,   42.54343414,   42.59529877, ...,   60.18870544,
#           60.61113358,   61.3196106 ],
#        [2915.71166992,   59.89926147,   59.96239471, ...,   75.72226715,
#           75.97126007,   77.21824646]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm025': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2315.17431641,   57.55050659,   57.52619171, ...,    0.        ,
#            0.        ,    0.        ],
#        [2314.67675781,   57.4571991 ,   57.4891243 , ...,   50.55488968,
#           50.8463707 ,   51.28361511],
#        [2315.89526367,   57.65486908,   57.58579254, ...,   50.55606842,
#           50.79636765,   51.27166748],
#        ...,
#        [2371.55493164,   60.46887589,   60.61870575, ...,   47.46322632,
#           47.79537964,   48.53904343],
#        [2378.01000977,   63.03831863,   63.15943527, ...,   49.048069  ,
#           49.24906158,   49.6965065 ],
#        [2423.82763672,   89.06111908,   88.82027435, ...,   64.15946198,
#           64.17082214,   64.85546112]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm026': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2001.98010254,  104.56106567,  104.8611145 , ...,    0.        ,
#            0.        ,    0.        ],
#        [2003.23657227,  104.82807159,  104.73763275, ...,   34.71223068,
#           34.77757645,   35.17394257],
#        [2000.87524414,  104.60457611,  104.54148102, ...,   34.60974121,
#           34.78128815,   35.18870926],
#        ...,
#        [2019.90539551,  106.33063507,  106.58538818, ...,   32.75345612,
#           32.9402504 ,   33.51795578],
#        [2023.60571289,  109.94477081,  109.73188782, ...,   33.50602722,
#           33.67687607,   34.16228867],
#        [2084.859375  ,  146.06199646,  146.39181519, ...,   41.47861481,
#           41.65797043,   42.11408615]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm027': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1701.40600586,   57.92357254,   58.11576843, ...,    0.        ,
#            0.        ,    0.        ],
#        [1702.33984375,   57.92702866,   57.96705246, ...,   44.56732559,
#           44.59945679,   45.57962799],
#        [1702.01843262,   57.84576416,   57.75562286, ...,   44.4305687 ,
#           44.80229568,   45.49582291],
#        ...,
#        [1762.20349121,   60.82400894,   60.84468079, ...,   40.44620132,
#           40.62046432,   41.21287918],
#        [1767.92724609,   63.14904785,   63.1129303 , ...,   41.27300262,
#           41.37596893,   42.0672493 ],
#        [1811.67480469,   86.58937073,   86.34236908, ...,   49.63798141,
#           49.91336823,   50.43476486]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm028': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2936.59008789,   44.60484314,   44.54499054, ...,    0.        ,
#            0.        ,    0.        ],
#        [2937.41674805,   44.57886505,   44.59663773, ...,   39.95996094,
#           39.85266876,   40.59150696],
#        [2935.80566406,   44.58083725,   44.62611771, ...,   39.74128723,
#           39.91540527,   40.6082077 ],
#        ...,
#        [2959.25585938,   46.80267334,   46.97330856, ...,   35.81446838,
#           36.1316452 ,   36.51929855],
#        [2963.28540039,   48.46614456,   48.38436127, ...,   36.80830002,
#           37.12769699,   37.46209335],
#        [3002.57958984,   64.74066925,   64.56791687, ...,   46.8272438 ,
#           46.86899567,   47.57188034]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm030': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[3181.26049805,   63.38597488,   63.33270264, ...,    0.        ,
#            0.        ,    0.        ],
#        [3181.17504883,   63.37352371,   63.41747284, ...,   61.55926132,
#           61.91496277,   62.83050156],
#        [3180.64331055,   63.25076294,   63.44932175, ...,   61.39005661,
#           61.86674881,   62.62376785],
#        ...,
#        [3248.8449707 ,   67.57054901,   67.58686066, ...,   56.8355484 ,
#           57.08542633,   58.06506348],
#        [3250.77832031,   69.62689972,   69.89273071, ...,   57.72524261,
#           58.22728729,   59.18141174],
#        [3288.21240234,   94.61304474,   95.03380585, ...,   71.26441193,
#           71.56186676,   72.02374268]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm031': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[3661.9152832 ,   85.14765167,   85.22148132, ...,    0.        ,
#            0.        ,    0.        ],
#        [3663.10546875,   85.39871216,   85.47437286, ...,   38.68437195,
#           38.98632812,   39.66482162],
#        [3660.70532227,   85.27803802,   85.5694809 , ...,   38.73355484,
#           38.96352768,   39.50780106],
#        ...,
#        [3677.19628906,   91.95635223,   91.68939209, ...,   34.49597168,
#           34.6771431 ,   35.10494995],
#        [3689.82543945,   95.23571777,   95.38049316, ...,   35.43313599,
#           35.59886551,   36.18135452],
#        [3760.66723633,  132.30056763,  132.09619141, ...,   46.45402145,
#           46.61852646,   47.17085266]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm032': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2874.03491211,   59.95158386,   60.17707062, ...,    0.        ,
#            0.        ,    0.        ],
#        [2876.70288086,   60.32407761,   60.10551453, ...,   82.88452148,
#           83.32662201,   84.61844635],
#        [2875.31738281,   60.03503036,   60.18304443, ...,   82.89741516,
#           83.31358337,   84.71738434],
#        ...,
#        [2873.95996094,   64.56104279,   64.483284  , ...,   72.60233307,
#           72.98969269,   73.88755798],
#        [2878.03369141,   67.64875793,   67.67070007, ...,   74.81180573,
#           75.59709167,   76.62445831],
#        [2945.87207031,  101.84860992,  102.50831604, ...,  101.05789185,
#          102.01727295,  103.14477539]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm034': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1637.62890625,   24.1319561 ,   24.154356  , ...,    0.        ,
#            0.        ,    0.        ],
#        [1636.63989258,   24.12846947,   24.22863197, ...,   53.86145401,
#           54.27135086,   55.05284119],
#        [1637.88269043,   24.11423874,   24.14702225, ...,   53.9403038 ,
#           54.33547974,   55.10559464],
#        ...,
#        [1741.73828125,   25.52486038,   25.51688957, ...,   43.80733109,
#           44.14054489,   44.63518524],
#        [1743.08605957,   26.51388359,   26.53171921, ...,   45.95639038,
#           46.21681213,   46.88250732],
#        [1777.34228516,   37.40654373,   37.31872177, ...,   68.61701202,
#           68.54980469,   69.40067291]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm036': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2175.50244141,   42.68602371,   42.5777092 , ...,    0.        ,
#            0.        ,    0.        ],
#        [2173.39428711,   42.65799713,   42.6667099 , ...,   48.23448181,
#           48.60826111,   49.00855637],
#        [2173.53051758,   42.57985306,   42.61475754, ...,   48.29403687,
#           48.47409439,   49.22670364],
#        ...,
#        [2205.78393555,   45.49290085,   45.5523262 , ...,   43.28862381,
#           43.42847443,   44.07796478],
#        [2208.62109375,   47.03889847,   47.1265564 , ...,   43.44083405,
#           43.79789734,   44.18694305],
#        [2240.5144043 ,   64.09118652,   63.91031647, ...,   45.44159317,
#           45.61521149,   46.4806366 ]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm037': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1694.68310547,   45.15156937,   45.11676407, ...,    0.        ,
#            0.        ,    0.        ],
#        [1698.02758789,   45.15335846,   45.02155304, ...,   44.29603958,
#           44.70994186,   45.56225204],
#        [1697.22558594,   45.1447258 ,   44.93295288, ...,   44.44376755,
#           44.91407013,   45.41305542],
#        ...,
#        [1736.35742188,   49.23447418,   49.43190384, ...,   37.74366379,
#           37.94758224,   38.39982986],
#        [1741.54406738,   51.28536987,   51.12025833, ...,   37.9797554 ,
#           38.1276474 ,   38.65695953],
#        [1781.94897461,   70.7464447 ,   70.9516983 , ...,   41.5060463 ,
#           41.70957184,   42.18538666]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm038': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1741.31420898,   34.65141678,   34.64116287, ...,    0.        ,
#            0.        ,    0.        ],
#        [1741.3190918 ,   34.65936279,   34.7466774 , ...,   34.99511719,
#           35.11014175,   35.80783081],
#        [1742.06225586,   34.545681  ,   34.62453461, ...,   34.9716835 ,
#           35.27908325,   35.63015366],
#        ...,
#        [1984.54980469,   37.73156738,   38.02139664, ...,   28.39089203,
#           28.52591324,   28.94900894],
#        [1986.66235352,   39.41252518,   39.39789963, ...,   29.51467514,
#           29.67489624,   30.10159302],
#        [2022.02783203,   54.60161591,   54.73020935, ...,   40.98423004,
#           40.95202637,   41.58455276]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm039': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2822.5871582 ,   51.71023941,   51.58111954, ...,    0.        ,
#            0.        ,    0.        ],
#        [2821.24243164,   51.60720825,   51.64792633, ...,   68.15789795,
#           68.55699921,   69.52075195],
#        [2822.03759766,   51.49757385,   51.57417297, ...,   68.29290009,
#           68.54383087,   69.4369278 ],
#        ...,
#        [2944.2512207 ,   57.32971191,   57.37096024, ...,   56.64317703,
#           57.03259277,   58.06792068],
#        [2948.75683594,   59.56364059,   59.51799011, ...,   58.23678207,
#           58.51176453,   59.26089096],
#        [2987.5456543 ,   81.37607574,   81.34078217, ...,   73.72776794,
#           73.9706192 ,   74.90447998]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm040': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1768.59606934,   58.29602814,   58.29859543, ...,    0.        ,
#            0.        ,    0.        ],
#        [1768.54016113,   58.20001602,   58.11302948, ...,   39.05242157,
#           39.12177658,   39.93577957],
#        [1769.67456055,   58.14144897,   58.15934753, ...,   39.04302216,
#           39.21290207,   39.91074371],
#        ...,
#        [2044.57348633,   62.10513687,   62.02023315, ...,   34.48866272,
#           34.64377213,   35.14509201],
#        [2050.60571289,   64.64513397,   64.69334412, ...,   35.59114838,
#           35.88686752,   36.33118439],
#        [2105.90283203,   91.15311432,   91.27074432, ...,   48.17916107,
#           48.42309952,   49.14427567]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm041': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1484.86450195,   79.61145782,   79.6475296 , ...,    0.        ,
#            0.        ,    0.        ],
#        [1485.4005127 ,   79.62208557,   79.82590485, ...,   51.02161026,
#           51.40049744,   52.52199936],
#        [1487.4296875 ,   79.62322998,   79.8493576 , ...,   50.89616013,
#           51.39848328,   52.27430725],
#        ...,
#        [1647.17700195,   84.42288971,   84.74041748, ...,   44.87008667,
#           45.29249573,   45.87525177],
#        [1651.91271973,   87.69300842,   87.63908386, ...,   46.23690033,
#           46.67641068,   47.09574127],
#        [1701.7154541 ,  121.24249268,  121.32878113, ...,   60.68342972,
#           60.86832428,   62.09514236]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm042': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1881.14477539,   37.01539993,   37.04286575, ...,    0.        ,
#            0.        ,    0.        ],
#        [1881.75097656,   36.96476746,   37.01670074, ...,   45.87400436,
#           46.17068863,   46.50570297],
#        [1882.47814941,   36.97171021,   37.00225449, ...,   45.74901962,
#           45.97650528,   46.8123436 ],
#        ...,
#        [1992.88208008,   39.54463196,   39.66007996, ...,   39.65819168,
#           39.92634201,   40.38389206],
#        [1994.90490723,   41.01526642,   41.03369904, ...,   40.73307419,
#           41.07959747,   41.53028488],
#        [2035.89562988,   55.01332092,   55.36091995, ...,   52.58634186,
#           52.97145081,   53.68143082]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm043': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2751.07788086,   53.08945847,   53.23743057, ...,    0.        ,
#            0.        ,    0.        ],
#        [2750.19165039,   53.25642776,   53.40442657, ...,   60.54553604,
#           61.13937759,   61.89929962],
#        [2753.31958008,   53.43299866,   53.24233627, ...,   60.66533661,
#           60.96772003,   61.83431625],
#        ...,
#        [2693.61010742,   57.27692795,   57.32080841, ...,   54.5281105 ,
#           54.80106735,   55.4422493 ],
#        [2693.99243164,   59.09334183,   59.16378784, ...,   55.86696625,
#           56.07186508,   57.04592896],
#        [2730.85131836,   79.87467194,   80.17900848, ...,   70.30986786,
#           70.90792084,   72.1493988 ]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm044': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2470.87133789,   51.67544937,   51.78540039, ...,    0.        ,
#            0.        ,    0.        ],
#        [2469.79858398,   51.91900635,   51.7763176 , ...,   68.62697601,
#           69.00086212,   70.04327393],
#        [2473.31176758,   51.75399017,   51.8296814 , ...,   68.51934814,
#           69.20755768,   70.07839203],
#        ...,
#        [2502.8112793 ,   53.43812561,   53.28794861, ...,   66.13747406,
#           66.34698486,   67.29878998],
#        [2502.30419922,   55.37559128,   55.75266266, ...,   67.66317749,
#           68.12594604,   68.78356171],
#        [2538.15063477,   78.49743652,   78.27225494, ...,   86.22766876,
#           86.63826752,   87.72733307]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm045': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2204.44238281,   76.68455505,   76.52644348, ...,    0.        ,
#            0.        ,    0.        ],
#        [2206.4453125 ,   76.7038269 ,   76.60948181, ...,   71.11386108,
#           71.21949768,   73.0599823 ],
#        [2205.078125  ,   76.72658539,   76.70941925, ...,   70.8575058 ,
#           71.33678436,   72.37866211],
#        ...,
#        [2073.17382812,   81.09654236,   80.73571014, ...,   65.01576996,
#           65.37097168,   66.16499329],
#        [2078.51318359,   83.67531586,   83.81958008, ...,   67.35033417,
#           67.40100098,   68.53900909],
#        [2142.8605957 ,  114.76541901,  114.32028961, ...,   90.86489868,
#           91.66721344,   93.15248871]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm046': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2238.57763672,   26.00859451,   25.98395729, ...,    0.        ,
#            0.        ,    0.        ],
#        [2237.6574707 ,   25.97980118,   26.03319168, ...,   40.88180923,
#           41.23734283,   41.70747375],
#        [2239.84716797,   26.01752472,   26.01635551, ...,   41.00611115,
#           41.15740585,   42.08815002],
#        ...,
#        [2266.3293457 ,   26.28088188,   26.2767334 , ...,   40.54428101,
#           40.96908569,   41.50166702],
#        [2271.74072266,   27.26564598,   27.22801208, ...,   41.74223328,
#           41.89343262,   42.6550293 ],
#        [2329.03393555,   37.70669174,   37.83421707, ...,   53.22955322,
#           53.36403275,   54.36650467]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm047': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2064.54321289,   97.72505188,   97.35009766, ...,    0.        ,
#            0.        ,    0.        ],
#        [2066.64379883,   97.4413681 ,   97.53232574, ...,   42.41250229,
#           42.58529663,   43.05246735],
#        [2064.00732422,   97.4444809 ,   97.48426056, ...,   42.32052612,
#           42.3932457 ,   43.03086472],
#        ...,
#        [2215.66674805,  110.50769806,  110.53378296, ...,   34.29818344,
#           34.55964279,   35.01640701],
#        [2217.2175293 ,  115.06348419,  115.26213074, ...,   35.47976303,
#           35.69515991,   36.12327957],
#        [2276.0065918 ,  164.47616577,  165.2233429 , ...,   46.78577042,
#           47.14527893,   47.81694412]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm048': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2768.91870117,   97.65673828,   97.78295135, ...,    0.        ,
#            0.        ,    0.        ],
#        [2769.77978516,   97.37005615,   97.62505341, ...,   37.15034485,
#           37.32120514,   37.61685562],
#        [2769.27709961,   97.76324463,   97.65841675, ...,   37.04243851,
#           37.29615402,   37.85090256],
#        ...,
#        [2774.25561523,  106.76249695,  106.68569183, ...,   32.13574219,
#           32.33741379,   32.68592072],
#        [2775.72680664,  111.46847534,  111.8482666 , ...,   33.22246933,
#           33.33079147,   33.83679962],
#        [2850.5168457 ,  160.91075134,  159.90454102, ...,   45.20196533,
#           45.39473343,   45.92296219]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm050': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1991.33508301,   51.68097687,   51.71722031, ...,    0.        ,
#            0.        ,    0.        ],
#        [1990.32824707,   51.7123642 ,   51.73503113, ...,   28.53809929,
#           28.74303055,   29.03497505],
#        [1989.90539551,   51.75427246,   51.63046265, ...,   28.51428413,
#           28.70926476,   29.44935226],
#        ...,
#        [2022.06347656,   56.3342514 ,   56.48927307, ...,   24.58699799,
#           24.74553871,   25.11494827],
#        [2025.0255127 ,   58.20475769,   58.47957611, ...,   25.2786541 ,
#           25.41646957,   25.80357552],
#        [2063.11743164,   79.37010193,   79.3881073 , ...,   33.25730896,
#           33.50024796,   33.91379929]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm051': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1383.12158203,   48.39323044,   48.34017563, ...,    0.        ,
#            0.        ,    0.        ],
#        [1383.6953125 ,   48.38862991,   48.27714539, ...,   54.33782578,
#           54.62294388,   55.43727112],
#        [1382.88208008,   48.33054352,   48.24726486, ...,   54.14795685,
#           54.49842834,   55.41989899],
#        ...,
#        [1534.34606934,   54.7659874 ,   54.78179932, ...,   43.41933441,
#           43.48749161,   44.27241898],
#        [1538.77734375,   56.72815323,   56.52940369, ...,   44.6315918 ,
#           44.90600204,   45.54615021],
#        [1576.95617676,   76.33268738,   76.48284149, ...,   58.34314346,
#           58.58381271,   59.3961792 ]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm052': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2684.66796875,   53.45007324,   53.54767227, ...,    0.        ,
#            0.        ,    0.        ],
#        [2758.82641602,   55.16289139,   55.3068924 , ...,   36.12558365,
#           36.2910347 ,   36.54214096],
#        [2635.85888672,   52.13552856,   52.02806473, ...,   36.02452469,
#           36.10444641,   36.73731232],
#        ...,
#        [2594.31591797,   54.77645493,   54.8249588 , ...,   33.86876678,
#           34.11349487,   34.56431961],
#        [2599.16748047,   56.73378372,   56.82873154, ...,   34.87136078,
#           34.91740417,   35.43096542],
#        [2646.92382812,   78.14717102,   78.04872131, ...,   43.41012573,
#           43.61368561,   44.21151733]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm053': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1689.82788086,   85.79119873,   85.5965271 , ...,    0.        ,
#            0.        ,    0.        ],
#        [1690.60839844,   85.63254547,   85.79610443, ...,   48.67964172,
#           48.64585876,   49.27549362],
#        [1691.52185059,   85.52519989,   85.40465546, ...,   48.44020081,
#           48.74964142,   49.33751297],
#        ...,
#        [1815.3190918 ,   97.00572205,   96.93576813, ...,   39.38507843,
#           39.46770859,   40.24760437],
#        [1822.71862793,   99.79341125,   99.88751984, ...,   39.99831009,
#           40.2168045 ,   40.71910095],
#        [1871.37524414,  132.23442078,  132.21833801, ...,   48.48162079,
#           48.67742538,   49.34192657]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm054': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1516.69506836,   52.77552795,   52.87819672, ...,    0.        ,
#            0.        ,    0.        ],
#        [1518.77392578,   52.9332695 ,   52.94231796, ...,   34.69691086,
#           34.71638489,   35.35019302],
#        [1518.94262695,   52.89688873,   52.7577095 , ...,   34.74443054,
#           34.82557297,   35.37941742],
#        ...,
#        [1692.12243652,   57.98563004,   58.11681747, ...,   29.38952827,
#           29.58112335,   29.9927597 ],
#        [1693.80688477,   60.11699295,   60.23936844, ...,   30.33494949,
#           30.45830154,   30.90509224],
#        [1735.52368164,   82.76789856,   82.57192993, ...,   39.73348236,
#           39.85848999,   40.4511261 ]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm055': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2170.12719727,   54.11418915,   53.9878006 , ...,    0.        ,
#            0.        ,    0.        ],
#        [2171.49438477,   54.23101807,   54.00911331, ...,   98.43282318,
#           99.46069336,  100.66150665],
#        [2171.71459961,   54.31843185,   54.2581749 , ...,   98.75016785,
#           99.30485535,  100.79309845],
#        ...,
#        [2237.49291992,   58.37969971,   58.29721069, ...,   83.81199646,
#           84.53533173,   85.71070862],
#        [2248.74462891,   60.88167953,   60.74917221, ...,   85.56521606,
#           86.45982361,   87.69775391],
#        [2317.03735352,   88.077034  ,   88.20892334, ...,  105.92166138,
#          106.71601868,  107.7811203 ]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm056': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[3026.02734375,   51.13334274,   51.14793015, ...,    0.        ,
#            0.        ,    0.        ],
#        [3026.45239258,   51.20443726,   51.13414383, ...,   50.75102615,
#           51.23797607,   51.95101929],
#        [3024.39257812,   51.13604736,   51.30759811, ...,   50.75699615,
#           50.87776566,   51.81163025],
#        ...,
#        [2662.52612305,   57.28874969,   57.33050156, ...,   43.20311356,
#           43.32504654,   43.98574448],
#        [2666.80249023,   59.48645401,   59.55879211, ...,   44.61834335,
#           45.00508118,   45.59939575],
#        [2714.01367188,   83.35803223,   83.69330597, ...,   61.51203156,
#           61.78724289,   62.25100327]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm057': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2535.01489258,   71.0766449 ,   71.21796417, ...,    0.        ,
#            0.        ,    0.        ],
#        [2536.85522461,   71.43790436,   71.54206848, ...,   73.17010498,
#           73.85118103,   74.87973022],
#        [2533.8840332 ,   71.2928009 ,   71.2713089 , ...,   73.47644806,
#           73.94293976,   74.92165375],
#        ...,
#        [2533.49731445,   77.91465759,   77.65729523, ...,   64.2642746 ,
#           64.58100128,   65.35806274],
#        [2538.63745117,   79.90737152,   80.39016724, ...,   65.04475403,
#           65.4152832 ,   66.32093811],
#        [2579.81738281,  106.10435486,  106.88552094, ...,   74.01898956,
#           74.24658203,   75.28033447]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm058': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[3023.41821289,   51.97546768,   51.81459427, ...,    0.        ,
#            0.        ,    0.        ],
#        [3020.56933594,   51.89928818,   51.91046524, ...,   44.66988373,
#           44.82103729,   45.43897629],
#        [3021.56713867,   51.94107819,   51.85808945, ...,   44.80494308,
#           45.14496994,   45.72489929],
#        ...,
#        [2814.20019531,   56.54499054,   56.42166138, ...,   39.20352173,
#           39.39824295,   39.99979401],
#        [2816.44189453,   58.29394913,   58.14367294, ...,   39.99120712,
#           40.30311584,   40.76484299],
#        [2867.62109375,   78.41616058,   78.12217712, ...,   49.45928955,
#           49.32289124,   50.59974289]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm059': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1881.92346191,   70.46912384,   70.56130219, ...,    0.        ,
#            0.        ,    0.        ],
#        [1881.66992188,   70.55977631,   70.48181152, ...,   57.99828339,
#           59.34640884,   59.88008499],
#        [1881.78295898,   70.40843201,   70.38045502, ...,   58.66285324,
#           58.88866425,   60.00252151],
#        ...,
#        [1915.19909668,   72.74504089,   72.5378418 , ...,   56.47421265,
#           56.92908096,   57.49882889],
#        [1919.19885254,   75.33094788,   75.44069672, ...,   58.16048431,
#           58.70539474,   59.45983505],
#        [1965.27636719,  105.07267761,  105.20002747, ...,   76.8478775 ,
#           76.94903564,   78.22715759]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm061': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1666.40283203,   45.78897858,   45.80511856, ...,    0.        ,
#            0.        ,    0.        ],
#        [1668.27478027,   45.89537048,   45.84713745, ...,   45.81657028,
#           45.76060486,   46.46828079],
#        [1668.30554199,   45.84765244,   45.78138733, ...,   45.59817886,
#           45.80001831,   46.61560822],
#        ...,
#        [1865.64746094,   50.68178177,   50.57281494, ...,   37.53527832,
#           37.85421753,   38.2570076 ],
#        [1869.63879395,   52.65657806,   52.71879959, ...,   38.66330338,
#           38.77190399,   39.31516647],
#        [1915.23791504,   74.69641876,   74.92797852, ...,   49.87249374,
#           50.07157516,   50.58139801]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm062': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[2421.06616211,   77.96720886,   78.32699585, ...,    0.        ,
#            0.        ,    0.        ],
#        [2421.77392578,   78.38275909,   78.38300323, ...,   52.89746094,
#           53.41371536,   54.40019608],
#        [2420.03540039,   78.11470032,   78.30220032, ...,   52.96727371,
#           53.11625671,   54.16366196],
#        ...,
#        [2527.46459961,   84.59666443,   84.43898773, ...,   44.72251511,
#           44.95402527,   45.24809647],
#        [2530.57446289,   88.2282486 ,   88.18990326, ...,   46.07312012,
#           46.35515594,   46.9635582 ],
#        [2596.94750977,  127.30218506,  127.42714691, ...,   61.38809204,
#           61.27493286,   62.36343384]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])], 'm063': [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]]), array([[1202.6817627 ,   59.59828949,   59.62443161, ...,    0.        ,
#            0.        ,    0.        ],
#        [1200.77233887,   59.6400032 ,   59.72908401, ...,   40.16205215,
#           40.52863693,   41.22394943],
#        [1202.5769043 ,   59.37563324,   59.61915207, ...,   40.20479202,
#           40.45619583,   41.2168541 ],
#        ...,
#        [1449.66674805,   64.58685303,   64.31461334, ...,   34.0450325 ,
#           34.27440262,   34.86621857],
#        [1452.33496094,   67.06956482,   67.34449005, ...,   35.14910889,
#           35.37755203,   35.91761398],
#        [1498.64160156,   95.52986908,   95.60948944, ...,   47.01522064,
#           47.3730545 ,   48.16221619]]), array([ 534,  535,  536, ..., 3604, 3605, 3606])]})

# %%
dd.keys()

# %%
masked_vis_dict = {}

for dish, (mask_flags, vis , nd_s0) in dd.items():
    masked_vis = MaskedArrayVisibilityFlags(vis, mask_flags, nd_s0)
    masked_vis_dict[dish] = masked_vis

# %%
masked_vis_dict.keys()

# %%
data = masked_vis_dict['m000']

# %%
data.filled()
data[1010:1030, 3001]

# %%
data = masked_vis_dict['m001']

# %%
data.filled()
data[1010:1030, 3001]

# %%
for ant_value in masked_vis_dict.keys():
    print(ant_value)

# %% [markdown]
# #### Waterfall Panel of the Raw Visibilities

# %%
#fixed the waterfall as a panel, used a compression list since the for/if loops was quite troublesome in plotting the correct reciever waterfall

rows = 1 #2
columns = 5

fig, axes = plt.subplots(nrows=rows, ncols=columns, figsize=(columns*5, rows*5))
[plot_waterfall(raw_vis_dict[ant_value], ax=ax, Title=f'Raw Visibilities {ant_value}', interpolation='nearest') for ant_value, ax in zip(raw_vis_dict, axes.flat) if ant_value in raw_vis_dict]
# Out:
# [<AxesSubplot:title={'center':'Raw Visibilities m001'}>,
#  <AxesSubplot:title={'center':'Raw Visibilities m002'}>,
#  <AxesSubplot:title={'center':'Raw Visibilities m003'}>,
#  <AxesSubplot:title={'center':'Raw Visibilities m004'}>,
#  <AxesSubplot:title={'center':'Raw Visibilities m005'}>]

# %% [markdown]
# #### Waterfall Panel of the Raw Visibilities with Level 1 masks applied

# %%
#fixed the waterfall as a panel, used a compression list since the for/if loops was quite troublesome in plotting the correct reciever waterfall

rows = 1 #2
columns = 5

fig, axes = plt.subplots(nrows=rows, ncols=columns, figsize=(columns*5, rows*5))
[plot_waterfall(masked_vis_dict[ant_value].filled(), ax=ax, Title=f'vis+l1_flags {ant_value}', interpolation='nearest') for ant_value, ax in zip(masked_vis_dict, axes.flat) if ant_value in masked_vis_dict]
# Out:
# [<AxesSubplot:title={'center':'vis+l1_flags m001'}>,
#  <AxesSubplot:title={'center':'vis+l1_flags m002'}>,
#  <AxesSubplot:title={'center':'vis+l1_flags m003'}>,
#  <AxesSubplot:title={'center':'vis+l1_flags m004'}>,
#  <AxesSubplot:title={'center':'vis+l1_flags m005'}>]

# %% [markdown]
# ## Sky Subtraction Method : ABBA

# %% [markdown]
# In this Section we will apply the ABBA method, which involves subtracting subsequent time-channels in the array, in this method our differencing is done over 4 channels in the TOD array.

# %%
#After the masking of the data and the flags we apply the sky-subtraction function
abba_ss_dict = {}
for ant_value,(masked_vis) in masked_vis_dict.items():
    # Applying the function to create SkySubtraction
    visSS_data = abba(masked_vis)
    abba_ss_dict[ant_value] = visSS_data


abba_ss_dict.keys()

stacked_visSS_abba = np.stack(list(abba_ss_dict.values()), axis=0)

# %%
SS_all_ants = stacked_visSS_abba

# %%
plot(SS_all_ants[:, 1010, 3000], Title='Sky-Subtractions of each antenna for a specific time and frequency channel', label='SS')  #this shows that the masked array Sky subs are now done as expected, we can see that for the four receivers there is a different sky-subtraction value
# Out:
# <AxesSubplot:title={'center':'Sky-Subtractions of each antenna for a specific time and frequency channel'}>

# %% [markdown]
# ### Bandpass plots of the ABBA Sky-Subtraction for each Receiver

# %%
#Note this one is inspecting at one frequency channel (residual data plot)

rows = 1 #2
columns = 5

fig, axes = plt.subplots(nrows=rows, ncols=columns, figsize=(columns*10, rows*5))
[plot(SS_all_ants[i, :, 3000], ylim= (-2,2), label= f" Receiver: {i} ", Title='Residual Data @ Freq channel: 3000', ax=ax) for i, ax in zip(range(0, len(ants)), axes.flat)]
# Out:
# [<AxesSubplot:title={'center':'Residual Data @ Freq channel: 3000'}>,
#  <AxesSubplot:title={'center':'Residual Data @ Freq channel: 3000'}>,
#  <AxesSubplot:title={'center':'Residual Data @ Freq channel: 3000'}>,
#  <AxesSubplot:title={'center':'Residual Data @ Freq channel: 3000'}>,
#  <AxesSubplot:title={'center':'Residual Data @ Freq channel: 3000'}>]

# %% [markdown]
# Bandpass plots for each receiver sky-subtraction, we want to check for the those strange spikes we see in the all antenna average, if its attributed to the averaging of the spectrums.

# %%
# Note this is the  ABBA SS Bandpass at each receiver
rows = 1 
columns = 5

fig, axes = plt.subplots(nrows=rows, ncols=columns, figsize=(columns*10, rows*5))
[plot(np.nanmean(SS_all_ants[i, :, :], axis=0), ylim= (-0.5,0.5), label= f" Receiver: {i} ", Title= f'Bandpass @ Receiver {i}', ax=ax) for i, ax in zip(range(0, len(ants)), axes.flat)]
# Out:
# [<AxesSubplot:title={'center':'Bandpass @ Receiver 0'}>,
#  <AxesSubplot:title={'center':'Bandpass @ Receiver 1'}>,
#  <AxesSubplot:title={'center':'Bandpass @ Receiver 2'}>,
#  <AxesSubplot:title={'center':'Bandpass @ Receiver 3'}>,
#  <AxesSubplot:title={'center':'Bandpass @ Receiver 4'}>]

# %%
def plot(x : np.ndarray, label=None, Title =None, ylim : tuple = None, figsize=(20, 6), ax=None, marker=None, linestyle=None):
    """Plot bandpass (visibility vs frequency channel)"""
    if ax is None:  # Create a new figure and axes if not being, passed in as a parameter
        fig, ax = plt.subplots(1, 1, figsize=figsize)
    ax.plot(x, label=label,marker =marker, linestyle=linestyle)
    ax.set_title(Title)
    ax.legend()

    
    if ylim is not None:
        ax.set_ylim(*ylim)
        
    return ax

# %% [markdown]
# ### Bandpass plot of the Antenna Averaged ABBA Sky-Subtraction (SSINS)

# %%
AbbaAllAnts = np.nanmean(SS_all_ants[:, :,:], axis=0)

plot(np.nanmean(AbbaAllAnts[:, :], axis=0), ylim= (-0.5,0.5), Title= f'Bandpass for SSINS', linestyle= '-', marker='')
# Out:
# No handles with labels found to put in legend.
# <AxesSubplot:title={'center':'Bandpass for SSINS'}>

# %% [markdown]
# ### Waterfall plots of the ABBA Sky-Subtraction for each Receiver

# %%
from matplotlib.colors import LogNorm

norm = LogNorm(vmin=0.01, vmax=1)
rows = 1 #2
columns = 5

fig, axes = plt.subplots(nrows=rows, ncols=columns, figsize=(columns*5, rows*5))
[plot_waterfall(abba_ss_dict[ant_value], ax=ax, Title=f'abba ss {ant_value}', interpolation='nearest', norm=norm) for ant_value, ax in zip(abba_ss_dict, axes.flat) if ant_value in abba_ss_dict]
# Out:
# [<AxesSubplot:title={'center':'abba ss m001'}>,
#  <AxesSubplot:title={'center':'abba ss m002'}>,
#  <AxesSubplot:title={'center':'abba ss m003'}>,
#  <AxesSubplot:title={'center':'abba ss m004'}>,
#  <AxesSubplot:title={'center':'abba ss m005'}>]

# %%
AbbaAllAnts = np.nanmean(np.abs(SS_all_ants[:, :,:]), axis=0)

# %% [markdown]
# ### Waterfall plot of the ABBA Sky-Subtraction Antenna Averaged (SSINS)

# %%
from matplotlib.colors import LogNorm

norm = LogNorm(vmin=1e-3, vmax=1)

plot_waterfall(AbbaAllAnts, interpolation='nearest', norm=norm, figsize=(20,12), Title= 'ABBA Incoherent Averaged Spectrum')
# Out:
# <AxesSubplot:title={'center':'ABBA Incoherent Averaged Spectrum'}>

# %% [markdown]
# ### RMS Statistics of the ABBA Sky-Subtractions

# %% [markdown]
# RMS Statistics of the sky-subtractions, to determine the level of noise reduction, the signal reduction should correspond to 1 over the square of the antennas we did the average over. I have done the RMS for all receivers, see a lot of differences.

# %%
#Check m000
rms = np.sqrt(np.nanmean(abba_ss_dict['m000']**2))
print(f'The RMS is:{rms}') 
rms_all_ants = np.sqrt(np.nanmean(AbbaAllAnts**2))
print(f'The RMS from averaging over all the receivers is:{rms_all_ants}')
# Out:
# The RMS is:0.4957309104534506
# The RMS from averaging over all the receivers is:0.489594208807211

# %%
#Check m001

rms = np.sqrt(np.nanmean(abba_ss_dict['m001']**2))
print(f'The RMS is: {rms}') 
rms_all_ants = np.sqrt(np.nanmean(AbbaAllAnts**2))
print(f'The RMS from averaging over all the receivers is: {rms_all_ants}')
# Out:
# The RMS is: 0.5683532541246146
# The RMS from averaging over all the receivers is: 0.489594208807211

# %%
len(ants[0:5]) #choose the first 5 Receivers
# Out:
# 5

# %%
rms_reduced_expected = 1/(np.sqrt(len(ants[0:5])))
print(f'The Expected Reduced RMS from averaging over all the receivers is: {rms_reduced_expected}') #Theoretical Value we expect
# Out:
# The Expected Reduced RMS from averaging over all the receivers is: 0.4472135954999579

# %%
# Expected RMS Values for each receiver
for ant_value, (abba_vis) in abba_ss_dict.items():
    rms =  np.sqrt(np.nanmean(abba_vis**2))
    d_rms = rms - rms_reduced_expected
    print(f'RMS for reciever {ant_value}  is : {rms}, The Expected RMS difference between the Receiver RMS and all antenna average RMS : {d_rms}')
# Out:
# RMS for reciever m000  is : 0.4957309104534506, The Expected RMS difference between the Receiver RMS and all antenna average RMS : 0.04851731495349265
# RMS for reciever m001  is : 0.5683532541246146, The Expected RMS difference between the Receiver RMS and all antenna average RMS : 0.12113965862465664
# RMS for reciever m002  is : 0.46474184186702744, The Expected RMS difference between the Receiver RMS and all antenna average RMS : 0.01752824636706951
# RMS for reciever m003  is : 0.5140225887058598, The Expected RMS difference between the Receiver RMS and all antenna average RMS : 0.06680899320590189
# RMS for reciever m004  is : 0.5116320902509869, The Expected RMS difference between the Receiver RMS and all antenna average RMS : 0.06441849475102895

# %%
# RMS for all Recievers ABBA Sky Subtraction

for ant_value, (abba_vis) in abba_ss_dict.items():
    rms =  np.sqrt(np.nanmean(abba_vis**2))
    d_rms = rms - rms_all_ants
    print(f'RMS for reciever {ant_value}  is : {rms}, The difference between the Receiver RMS and all antenna average RMS : {d_rms}')
# Out:
# RMS for reciever m000  is : 0.4957309104534506, The difference between the Receiver RMS and all antenna average RMS : 0.006136701646239584
# RMS for reciever m001  is : 0.5683532541246146, The difference between the Receiver RMS and all antenna average RMS : 0.07875904531740358
# RMS for reciever m002  is : 0.46474184186702744, The difference between the Receiver RMS and all antenna average RMS : -0.024852366940183557
# RMS for reciever m003  is : 0.5140225887058598, The difference between the Receiver RMS and all antenna average RMS : 0.024428379898648822
# RMS for reciever m004  is : 0.5116320902509869, The difference between the Receiver RMS and all antenna average RMS : 0.022037881443775886

# %% [markdown]
#  #### RMS Result Discussion:
#
# The RMS value is  higher when we averaged over all antennas for this particular test of 5 receivers, compared to the expected RMS from theory.
# The RMS value we expect from averaging in theory is 0.4472135954999579
# however we computed an RMS value from averaging over our antennas to be 0.489594208807211
#
# This indicates that the observed RMS value (0.489594208807211) is about 9.48% higher than the expected RMS value (0.4472135954999579).

# %% [markdown]
# ### Histogram plots of the ABBA Sky-Subtraction Waterfalls

# %%
rows = 1 #2
columns = 5

fig, axes = plt.subplots(nrows=rows, ncols=columns, figsize=(columns*5, rows*5))
[plot_hist(np.ravel(abba_ss_dict[ant_value]),label= f" Receiver: {ant_value} ", Title=f'Histogram for Residual data of Receiver {ant_value}', bins=1000, xlim=(-5,5), ax=ax) for ant_value, ax in zip(abba_ss_dict, axes.flat) if ant_value in abba_ss_dict]
# Out:
# [<AxesSubplot:title={'center':'Histogram for Residual data of Receiver m001'}>,
#  <AxesSubplot:title={'center':'Histogram for Residual data of Receiver m002'}>,
#  <AxesSubplot:title={'center':'Histogram for Residual data of Receiver m003'}>,
#  <AxesSubplot:title={'center':'Histogram for Residual data of Receiver m004'}>,
#  <AxesSubplot:title={'center':'Histogram for Residual data of Receiver m005'}>]

# %%
def plot_hist(x : np.ndarray, label=None, Title =None, xlim : tuple = None, figsize=None, ax=None, bins=None, alpha=None, density=None, color=None ,edgecolor=None, histtype=None, xlabel=None, ylabel=None):
   
    if ax is None:  # Create a new figure and axes if not being passed in as a parameter
        fig, ax = plt.subplots(1, 1, figsize=figsize)
    ax.hist(x, label=label,bins=bins, alpha=alpha, density=density, color=color, edgecolor=edgecolor, histtype=histtype)
    ax.legend()
    ax.set_title(Title)
    ax.set_xlabel(xlabel=xlabel)
    ax.set_ylabel(ylabel=ylabel)
    if xlim is not None:
        ax.set_xlim(*xlim)
        
    return ax

# %% [markdown]
# ### Histogram plots of the ABBA Antenna Averaged Sky-Subtraction Waterfalls (SSINS)

# %%
 plot_hist(np.ravel(np.abs(AbbaAllAnts)),label= " All Antenna Distribution", Title=f'All Antenna ABBA SS Average Residual Distribution', bins=1000, xlim=(0,2.5), figsize=(20,12), histtype='step')
# Out:
# <AxesSubplot:title={'center':'All Antenna ABBA SS Average Residual Distribution'}>

# %% [markdown]
# Diagram : https://app.diagrams.net/?src=about
# Statistics: https://stackoverflow.com/questions/45483890/how-to-correctly-use-scipys-skew-and-kurtosis-functions

# %%
from scipy import stats 

# Null Hypothesis : This test will help us determine wether the residual data is normally distributed.

# %%
abba_ss_dict.keys()
# Out:
# dict_keys(['m000', 'm001', 'm002', 'm003', 'm004'])

# %%
x = abba_ss_dict['m003'] # Test the scipy stats on one ss item

# %%
xx = x[:,3001]          # Choose  all time channels, and  a specific frequency to run this test
xx
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
y = xx[~np.isnan(xx)]  # Exclude the nans, since the following error occurs with nan_policy='omit' :  ValueError: kurtosistest requires at least 5 observations; 0 observations were given.
y.shape
# Out:
# (1252,)

# %%
res_x = stats.normaltest(y)  # This test had the default option of two-sided, which checks if the kurtosis of the distribution is different from a normal distribution, so if the p-value is small we can reject this hypothesis
res_x.pvalue

# pvalue = 1.5664087424312112e-06 is very small indicates that we reject the null (null was set as that our distribution is different from a normal)
# Out:
# 1.5664087424312112e-06

# %%
#z_score = ((IncoherentSpectrum-meanEst))/np.sqrt(c*np.nansum((IncoherentSpectrum - meanEst)**2)/no_dishes)

# %% [markdown]
# ### Z- Score Calculation of the ABBA Incoherent Averaged Spectrum

# %%
def cal_zscore(SS_all_spectrums):

    """ This fuction calculates the z-scores.
    Parameters:
    ----------
    SS_all_spectrums: Array of all antenna sky subtraction spectrums, has the shape (no.Dishes, Time, Frequency)
    
    Returns:
    --------

    z_score: 2D array of the normalised Incoherent Spectrum.
    
    """
    
    IncoherentSpectrum = np.nanmean(np.abs(SS_all_spectrums), axis=0)
    no_dishes = SS_all_spectrums.shape[0]
    c_fold = np.pi / 2 - 1  #Auto C_fold Ratio
    meanEst = np.nanmean(IncoherentSpectrum, axis=0) #Time axis averaged MeanEstimate
    std_sq = c_fold*meanEst**2 
    print(std_sq)
    #z_score = ((IncoherentSpectrum-meanEst))/np.sqrt(c_fold*std_sq/no_dishes)
    z_score = ((IncoherentSpectrum-meanEst))/np.sqrt(std_sq/no_dishes)
   
    
    return z_score  #returns 2D array of the z scores

# %%
z_score_map_abba = cal_zscore(SS_all_ants)
# Out:
# [nan nan nan ... nan nan nan]

# %%
z_score_map_abba.shape
# Out:
# (3942, 4096)

# %%
min= np.nanmin(z_score_map_abba)
max = np.nanmax(z_score_map_abba)
mean =np.nanmean(z_score_map_abba)
median = np.nanmedian(z_score_map_abba)

print(f'z_score_map_abba minimum val is: {min}')
print(f'z_score_map_abba maximum val is: {max}')
print(f'z_score_map_abba mean val is: {mean}')
print(f'z_score_map_abba median val is: {median}')
print(f'z_score_map_abba range val is: {max-min}')
# Out:
# z_score_map_abba minimum val is: -50.68266352735427
# z_score_map_abba maximum val is: 284.134263346188
# z_score_map_abba mean val is: 6.6190313442545074e-18
# z_score_map_abba median val is: -0.0003549183961887042
# z_score_map_abba range val is: 334.8169268735423

# %%
min= np.nanmin(z_score_map_abba)
max = np.nanmax(z_score_map_abba)
mean =np.nanmean(z_score_map_abba)
median = np.nanmedian(z_score_map_abba)

print(f'z_score_map_abba minimum val is: {min}')
print(f'z_score_map_abba maximum val is: {max}')
print(f'z_score_map_abba mean val is: {mean}')
print(f'z_score_map_abba median val is: {median}')
print(f'z_score_map_abba range val is: {max-min}')
# Out:
# z_score_map_abba minimum val is: -22.389564921570674
# z_score_map_abba maximum val is: 129.4422507678936
# z_score_map_abba mean val is: 2.2988913464109536e-17
# z_score_map_abba median val is: -0.004077191368663016
# z_score_map_abba range val is: 151.83181568946426

# %%
def plot_waterfall(x,label=None,  Title =None, ylim : tuple = None, figsize=None, ax=None, vmax=None,vmin=None, interpolation= None, norm=None, cmap=None, xlabel=None, ylabel=None):

    if ax is None:  # Create a new figure and axes if not being passed in as a parameter
        fig, ax = plt.subplots(1, 1, figsize=figsize)
    im = ax.imshow(x, label=label, vmax=vmax, vmin=vmin, interpolation=interpolation, cmap='viridis', aspect='auto', norm=norm)
    ax.set_title(Title)
    ax.set_xlabel(xlabel=xlabel)
    ax.set_ylabel(ylabel=ylabel)
    fig.colorbar(im, ax=ax) 
    
    if ylim is not None:
        ax.set_ylim(*ylim)
    return ax

# %%
norm = LogNorm(vmin=1e-3, vmax=1e1)

plot_waterfall(z_score_map_abba, Title = 'Z Score Waterfall (ABBA Sky-Subtraction)', figsize=(20,12), xlabel='Frequency Chan', ylabel='Time Chan', interpolation='nearest', norm=norm)
# Out:
# <AxesSubplot:title={'center':'Z Score Waterfall (ABBA Sky-Subtraction)'}, xlabel='Frequency Chan', ylabel='Time Chan'>

# %% [markdown]
# ### Z-Score Waterfall

# %%
from matplotlib.colors import LogNorm
import matplotlib as mpl
cmap = mpl.cm.viridis
bounds =[-6,-5.5,-5,-4.5,-3, -2,-1,0,1,2,3,4.5,5, 5.5, 6]

norm = mpl.colors.BoundaryNorm(bounds, cmap.N, extend='both')
plot_waterfall(z_score_map_abba, Title = 'Z Score Waterfall (ABBA Sky-Subtraction)', figsize=(20,12), cmap=cmap, norm=norm, xlabel='Frequency Chan', ylabel='Time Chan', interpolation='nearest' )
# Out:
# <AxesSubplot:title={'center':'Z Score Waterfall (ABBA Sky-Subtraction)'}, xlabel='Frequency Chan', ylabel='Time Chan'>

# %%
print(f'Z map data shape:{z_score_map_abba.shape}')
print(f'L4 mask data shape:{mask_l4.shape}')

#Shapes of the z map and mask_l4 are different, i have reshaped the masked_l4 array to match the z map data
# Out:
# Z map data shape:(3942, 4096)
# L4 mask data shape:(3945, 4096)

# %%
z_data_shape = z_score_map_abba.shape
resized_mask_l4 = np.resize(mask_l4, z_data_shape)

# %%
z_map_abba_l4_masked = np.ma.masked_array(z_score_map_abba, mask=resized_mask_l4, fill_value = np.nan)

# %%
plot_waterfall(z_map_abba_l4_masked, interpolation='nearest', norm=norm, Title = 'Z Score Waterfall (ABBA Sky-Subtraction) + level 4 Mask', figsize=(20,12), xlabel='Frequency Chan', ylabel='Time Chan' )
# Out:
# <AxesSubplot:title={'center':'Z Score Waterfall (ABBA Sky-Subtraction) + level 4 Mask'}, xlabel='Frequency Chan', ylabel='Time Chan'>

# %% [markdown]
# ### Z-Score Distribution

# %%
plot_hist(np.ravel(z_score_map_abba),label= " All Antenna Distribution", Title=f'Z-Score Histogram', bins=1000, xlim=(-2.5, 2.5), figsize=(20,12))
# Out:
# <AxesSubplot:title={'center':'Z-Score Histogram'}>

# %% [markdown]
# ### Sky Subtraction method : Time Differencing

# %% [markdown]
# ### Scipy Statistics of the ABBA Sky-Subtraction Waterfall Arrays
# I still have more tests to run, but this will be the general approach im thinking about taking for evaluating the kurtosis, not sure if i should use np.ravel(ss_waterfalls)

# %%
#After the masking of the data and the flags we apply the sky-subtraction function
SS_dict = {}
for ant_value,(masked_vis) in masked_vis_dict.items():
    # Applying the function to create SkySubtraction
    SS_data = SkySubtraction(masked_vis)
    SS_dict[ant_value] = SS_data

# %%
SS_dict.items()
# Out:
# dict_items([('m000', array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])), ('m001', array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])), ('m002', array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])), ('m003', array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])), ('m004', array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]]))])

# %%
ss_vis = np.stack(list(SS_dict.values()), axis=0)

# %%
ss_vis_AllAntsAve = np.nanmean(np.abs(ss_vis[:,:,:]), axis=0)

# %%
ss_vis_AllAntsAve.shape
# Out:
# (3646, 4096)

# %%
z_score_map_ss = cal_zscore(ss_vis)

# %%
from matplotlib.colors import LogNorm

norm = LogNorm(vmin=1e-1, vmax=1.5e-1)

plot_waterfall(z_score_map_ss, interpolation='nearest', norm=norm, Title = 'Z Score Waterfall (2 time channel Sky-Subtraction)', figsize=(20,12) )
# Out:
# <AxesSubplot:title={'center':'Z Score Waterfall (2 time channel Sky-Subtraction)'}>

# %%
z_data_shape = z_score_map_ss.shape
resized_mask_l4 = np.resize(mask_l4, z_data_shape)

# %%
z_map_ss_l4_masked = np.ma.masked_array(z_score_map_ss, mask=resized_mask_l4, fill_value = np.nan)

# %%
from matplotlib.colors import LogNorm

norm = LogNorm(vmin=1e-1, vmax=1.5e-1)

plot_waterfall(z_map_ss_l4_masked, interpolation='nearest', norm=norm, Title = 'Z Score Waterfall (2 time channel Sky-Subtraction) + Level 4 Mask', figsize=(20,12) )
# Out:
# <AxesSubplot:title={'center':'Z Score Waterfall (2 time channel Sky-Subtraction) + Level 4 Mask'}>

# %% [markdown]
# ### Comparision plots of the sky subtacion with lower level flags

# %%
from matplotlib.colors import LogNorm
norm = LogNorm(vmin=1e-3, vmax=1e-1)
fig, axes = plt.subplots(1,3, figsize=(22,12))


im0 = axes[0].imshow(z_score_map_abba, interpolation='nearest', norm=norm )
axes[0].set_title('Z Score Waterfall (ABBA Sky-Subtraction)')
axes[0].set_xlabel('Frequency Chan')
axes[0].set_ylabel('Time Chan')

im1 = axes[1].imshow(z_score_map_ss, interpolation='nearest', norm=LogNorm(vmin=1e-1, vmax=1.5e-1))
axes[1].set_title('Z Score Waterfall (2 Time Channel Sky-Subtraction)')
axes[1].set_xlabel('Frequency Chan')
axes[1].set_ylabel('Time Chan')


im2 = axes[2].imshow(masked_vis_dict['m000'].filled(), interpolation='nearest')
axes[2].set_title('Raw Visibility + Level 1 Flags, Receiver m000')
axes[2].set_xlabel('Frequency Chan')
axes[2].set_ylabel('Time Chan')

for ax, im in zip(axes, [im0, im1, im2]):
    cbar = plt.colorbar(im, ax=ax,fraction=0.04, pad=0.03)
    #cbar.set_label('Colorbar Label')


fig.suptitle('Comparision plots of the z score maps with lower level Flags')
plt.subplots_adjust(top=1.25)
plt.savefig('Comparision plots of the z score maps with lower level Flags.png')

plt.show()

# %%
l4_flags_dict = {}
mask_dir = Path('/idia/projects/hi_im/raw_vis/MeerKLASS2021/level4/mask/')
for dish, (vis) in raw_vis_dict.items():
    try:
        with open(mask_dir / f'{fname}_{dish}_level4_mask2', 'rb') as f:
            d3 = pickle.load(f)
            print(d3.keys())
    except(Exception):
        try:
            with open(mask_dir / f'{fname}_{dish}_level4_mask', 'rb') as f:
                d3 = pickle.load(f)
                print(f'mask loaded for dish {dish}')
    
        except FileNotFoundError:
            print(f'No mask file found for dish {dish}')
            
    mask_flags=d3['Inten_mask']
    l4_flags_dict[dish]  = mask_flags
# Out:
# mask loaded for dish m001
# mask loaded for dish m002
# mask loaded for dish m003
# mask loaded for dish m004
# mask loaded for dish m005
# mask loaded for dish m006
# mask loaded for dish m007
# mask loaded for dish m008
# mask loaded for dish m009
# mask loaded for dish m010
# mask loaded for dish m011
# mask loaded for dish m012
# mask loaded for dish m013
# mask loaded for dish m015
# mask loaded for dish m016
# mask loaded for dish m017
# mask loaded for dish m018
# mask loaded for dish m019
# mask loaded for dish m020
# mask loaded for dish m021
# mask loaded for dish m022
# mask loaded for dish m023
# mask loaded for dish m025
# mask loaded for dish m026
# mask loaded for dish m027
# mask loaded for dish m028
# mask loaded for dish m030
# mask loaded for dish m031
# mask loaded for dish m032
# mask loaded for dish m034
# mask loaded for dish m036
# mask loaded for dish m037
# mask loaded for dish m038
# mask loaded for dish m039
# mask loaded for dish m040
# mask loaded for dish m041
# mask loaded for dish m042
# mask loaded for dish m043
# mask loaded for dish m044
# mask loaded for dish m045
# mask loaded for dish m046
# mask loaded for dish m047
# mask loaded for dish m048
# mask loaded for dish m050
# mask loaded for dish m051
# mask loaded for dish m052
# mask loaded for dish m053
# mask loaded for dish m054
# mask loaded for dish m055
# mask loaded for dish m056
# mask loaded for dish m057
# mask loaded for dish m058
# mask loaded for dish m059
# mask loaded for dish m061
# mask loaded for dish m062
# mask loaded for dish m063

# %%
l4_flags_dict.keys()
# Out:
# dict_keys(['m001', 'm002', 'm003', 'm004', 'm005', 'm006', 'm007', 'm008', 'm009', 'm010', 'm011', 'm012', 'm013', 'm015', 'm016', 'm017', 'm018', 'm019', 'm020', 'm021', 'm022', 'm023', 'm025', 'm026', 'm027', 'm028', 'm030', 'm031', 'm032', 'm034', 'm036', 'm037', 'm038', 'm039', 'm040', 'm041', 'm042', 'm043', 'm044', 'm045', 'm046', 'm047', 'm048', 'm050', 'm051', 'm052', 'm053', 'm054', 'm055', 'm056', 'm057', 'm058', 'm059', 'm061', 'm062', 'm063'])

# %%
vis_data = raw_vis_dict['m001']
mask_l4 = l4_flags_dict['m001']

l4_masked_data = np.ma.masked_array(vis_data, mask=mask_l4, fill_value = np.nan)

# %%
from matplotlib.colors import LogNorm
norm = LogNorm(vmin=1e-6, vmax=1e-2)
fig, axes = plt.subplots(1,3, figsize=(22,12))


im0 = axes[0].imshow(z_score_map_abba, interpolation='nearest', norm=norm )
axes[0].set_title('Z Score Waterfall (ABBA Sky-Subtraction)')
axes[0].set_xlabel('Frequency Chan')
axes[0].set_ylabel('Time Chan')

im1 =axes[1].imshow(z_score_map_ss, interpolation='nearest', norm=norm )
axes[1].set_title('Z Score Waterfall (2 Time Channel Sky-Subtraction)')
axes[1].set_xlabel('Frequency Chan')
axes[1].set_ylabel('Time Chan')


im2 = axes[2].imshow(l4_masked_data, interpolation='nearest')
axes[2].set_title('Raw Visibility + Level 4 Flags, Receiver m000')
axes[2].set_xlabel('Frequency Chan')
axes[2].set_ylabel('Time Chan')

for ax, im in zip(axes, [im0, im1, im2]):
    cbar = plt.colorbar(im, ax=ax,fraction=0.04, pad=0.03)
    #cbar.set_label('Colorbar Label')

 
fig.suptitle('Comparision plots of the z score maps with lower level Flags')
plt.subplots_adjust(top=1.25)
plt.savefig('Comparision plots of the z score maps with lower level Flags.png')
plt.show()

# %%
#Understanding Z-scores

data = np.array([[5, 6, 7, 7, 8],
                 [8, 8, 8, 9, 9],
                 [2, 2, 4, 4, 5]])

# %%
data.shape
# Out:
# (3, 5)

# %%
np.mean(data, axis=1)
# Out:
# array([6.6, 8.4, 3.4])

# %%
plot_waterfall(data)
# Out:
# <AxesSubplot:>

# %%
z_score =[(x-np.mean(data, axis=0))/np.std(data) for x in data]

# %%
z_score
# Out:
# [array([0.        , 0.29285371, 0.29285371, 0.14642685, 0.29285371]),
#  array([1.31784168, 1.17141483, 0.73213427, 1.02498797, 0.73213427]),
#  array([-1.31784168, -1.46426853, -1.02498797, -1.17141483, -1.02498797])]

# %%
bounds = [-1, -0.5, 0, 0.5, 1]
norm = mpl.colors.BoundaryNorm(bounds, cmap.N, extend='both')
plot_waterfall(z_score, norm=norm)
# Out:
# <AxesSubplot:>

# %%
plot_hist(np.ravel(z_score), bins=20)
# Out:
# No handles with labels found to put in legend.
# <AxesSubplot:>
