# %%
# Parameters
block_number = 1234567
pol = "h"

# %% [markdown]
# # Test notebook
# This noteboook should be executed with papermill CLI, passing in `block_number` and `pol` parameters. The injected parameters will be inserted as a first code cell of the notebook

# %%
print(f"Welcome to the test notebook: block_number = {block_number}, pol = {pol}")
# Out:
# Welcome to the test notebook: block_number = 1234567, pol = h
